# %%
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Simulation 6</span>
# #### <span style="color:orange">  Exercise 6.01</span>

# %% [markdown]
# In this exercise the one dimensional Ising model, which is fully resoluble, will be analized thruogh the study of the main thermodynamic quantities. This quantities, internal energy, heat capacity,magnetic suseptibily and magnetization are fully derivable thanks to the partition function Z.
# The Hamiltonian for a system of N spins with nearest neighbors interaction is given by ($\mu_B=1$ and $k_B=1$):
#
# $$
# H =
# -J\sum_{i=1}^N s_i s_{i+1}
# -\frac{h}{2}\sum_{i=1}^N (s_i + s_{i+1})
# $$
#
# where $\{ s_i \}_{i=1,N}$ are spin variables taking values in $\{-1;1\}$, $J>0$ (ferromagnetic model),and with the assumption $s_{N+1} = s_{1}$.
#
# The partition function for $N$ spins, $Z$ is:
#
# $$
# Z=\sum_{\{ s_i \}} \exp \left( -\beta H\right) = \lambda_1^N + \lambda_2^N
# $$
#
# where
# $\lambda_{1,2} =
# e^{\beta J}
# \cosh (\beta h) \pm \left[ e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J) \right]^{1/2}$,
# and where $\beta=\frac{1}{k_b T} = \frac{1}{T}$.
# The thermodynamical quantities are give by:
# - the **Internal Energy** per spin (with $h=0$):
#
# $$
# \frac{U(N,T)}{N} = \frac{\langle H \rangle}{N}
# = \frac{1}{N} \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}
# = -\frac{1}{N}\frac{\partial \ln Z}{\partial \beta}
# \underset{h=0}= -J \tanh (\beta J) \Biggl( \frac{1 + \tanh^{N-2} (\beta J)}{1+\tanh^N (\beta J)} \Biggl)
# $$
#
# - the **Heat Capacity** (with $h=0$):
#
# $$
# C(N,T) = \frac{\partial U(N,T)}{\partial T}
# = \frac{\partial \beta}{\partial T}\frac{\partial U}{\partial \beta}
# = -k_B\beta^2 \frac{\partial}{\partial \beta} \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z} \right] = \\
# = -k_B\beta^2 \left[ -\sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \sum_{\{ s_i \}} H \exp \left( -\beta H\right)\frac{\partial Z^{-1}}{\partial \beta} \right] = \\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} + \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]\frac{1}{Z}\frac{\partial Z}{\partial \beta} \right\} =\\
# = k_B\beta^2 \left\{ \sum_{\{ s_i \}} H^2 \frac{\exp \left( -\beta H\right)}{Z} - \left[ \sum_{\{ s_i \}} H \frac{\exp \left( -\beta H\right)}{Z}\right]^2 \right\} =
# k_B\beta^2 \left(\langle H^2 \rangle -\langle H \rangle^2 \right)
# $$
#
# $$
# \frac{C(N,T)}{N} = \frac{1}{N}\frac{\partial U(N,T)}{\partial T} =\\
# \underset{h=0}=
# k_B (\beta J)^2 \left\{ 1+\tanh^N (\beta J)+(N-1)\tanh^2 (\beta J)+(N-1)\frac{\tanh^{N-2} (\beta J)}{1+\tanh^N (\beta J)}
# - N \left[ \frac{\tanh (\beta J) + \tanh^{N-1} (\beta J)}{1+\tanh^N (\beta J)} \right]^2 \right\}
# $$
#
# - The **magnetization** (with $h = 0.02$):
#
# With $h=0$ the magnetization $M(N,T,h=0)=\langle \sum_{i=1,N}s_i \rangle =0$ because in 1D we cannot have a (ferromagnetic) phase transition in absence of an external magnetic field.
#
# $$
# M(N,T,h) = -\frac{\partial A}{\partial h} = k_B T \frac{\partial \ln Z}{\partial h} =
# \frac{1}{\beta} \frac{1}{Z}\frac{\partial}{\partial h}\sum_{\{ s_i \}} \exp \left( -\beta H\right) = \sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z} = \left\langle \sum_{i=1,N}s_i \right\rangle
# $$
#
# The exact formula from $M(N,T,h) = k_B T \dfrac{\partial \ln Z}{\partial h}$ is:
# $$
# \frac{M(N,T,h)}{N}=\frac{e^{\beta J}\; \sinh(\beta h)}{Z} \; \Bigl[\lambda_1^{N-1}\cdot \Bigl(1+\frac{e^{\beta J}\; \cosh(\beta h)}{\sqrt{e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J)}}\Bigr) + \lambda_2^{N-1}\cdot \Bigl(1-\frac{e^{\beta J}\; \cosh(\beta h)}{\sqrt{e^{2\beta J} \cosh^2 (\beta h) - 2\sinh (2\beta J)}}\Bigr)\Bigr]
# $$
#
# - The **magnetic susceptibility** (with $h=0$):
#
# $$
# \chi(N,T) = \frac{\partial M}{\partial h} =
# \frac{\partial}{\partial h}\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z} =\\
# = \beta\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right]^2 \frac{\exp \left( -\beta H\right)}{Z}
# -\sum_{\{ s_i \}} \left[ \sum_{i=1,N}s_i\right] \frac{\exp \left( -\beta H\right)}{Z}
# \frac{1}{Z}\frac{\partial Z}{\partial h} =
# \beta \left[ \left\langle \left( \sum_{i=1,N}s_i \right)^2 \right\rangle - \left\langle \sum_{i=1,N}s_i \right\rangle^2 \right] = \\
# \underset{h=0}= \beta \left[ \left\langle \left( \sum_{i=1,N}s_i \right)^2 \right\rangle \right] = \beta e^{2\beta J} \Biggl( \frac{1-\tanh^N (\beta J)}{1+\tanh^N (\beta J)} \Biggl)
# $$
#
#
# In this exercise this quantities will be computed using two different sampling algorithms, Metropolis and Gibbs and the quantities will be plotted as function of the temperature, T, in a range [0.5, 2.0].

# %% [markdown]
# ### INTERNAL ENERGY(h=0)

# %%
#U : internal energy
#theoretical result 
plt.figure(figsize =(18,10))
points=100
T = np.linspace(0.2,3.0,num=points)
beta = 1/T
J = 1.0
Ns = 50
th = np.tanh(J/T)
thN= th**Ns
ch = 1/th
e = -J*( th + ch*thN )/( 1 + thN )

plt.subplot(2,2,1)
Temp, eneGibbs,stdGibbs = np.loadtxt("isingData/h0/enGibbs.dat", usecols = (0,2,3), unpack = True)
plt.errorbar(Temp, eneGibbs, yerr=stdGibbs, label = "MC simulation: Metropolis", fmt = "ko", capsize = 5, elinewidth = 1)
plt.plot(T, e, label = "Analytic result", color = "red")
plt.title('U/N: Gibbs sampling',fontsize = 15)
plt.xlim(0,2.5)
plt.xlabel('Temperature',fontsize = 12)
plt.ylabel('U/N',fontsize = 15)
plt.legend(loc = "best")
plt.grid(True)

plt.subplot(2,2,2)
Temp, eneMetro,stdMetro = np.loadtxt("isingData/h0/enMetro.dat", usecols = (0,2,3), unpack = True)
plt.errorbar(Temp, eneMetro, yerr=stdMetro, label = "MC simulation: Gibbs", fmt = "bx", capsize = 5, elinewidth = 1)
plt.plot(T, e, label = "Analytic result", color = "red")
plt.title('U/N: Metropolis sampling',fontsize = 15)
plt.xlim(0,2.5)
plt.xlabel('Temperature',fontsize = 15)
plt.ylabel('U/N',fontsize = 15)
plt.legend(loc = "best")
plt.grid(True)

plt.subplot(2,2,3)
Temp, eneMetro,stdMetro = np.loadtxt("isingData/h0/enMetro.dat", usecols = (0,2,3), unpack = True)
plt.errorbar(Temp, eneMetro, yerr=stdMetro, label = "MC simulation: Gibbs", fmt = "bx", markersize = 10 , capsize = 5, elinewidth = 1)
Temp, eneGibbs,stdGibbs = np.loadtxt("isingData/h0/enGibbs.dat", usecols = (0,2,3), unpack = True)
plt.errorbar(Temp, eneGibbs, yerr=stdGibbs, label = "MC simulation: Metropolis", fmt = "ko", capsize = 5, elinewidth = 1)
plt.plot(T, e, label = "Analytic result", color = "red")
plt.title('U/N: Gibbs vs. Metropolis',fontsize = 12)
plt.xlim(0,2.5)
plt.xlabel('Temperature',fontsize = 12)
plt.ylabel('U/N',fontsize = 12)
plt.legend(loc = "best")
plt.grid(True)

# %% [markdown]
# ### HEAT CAPACITY(h=0)

# %%
#heat capacity
plt.figure(figsize =(18,10))
points=100
T = np.linspace(0.2,3.0,num=points)
beta = 1/T
J = 1.0
Ns = 50
th = np.tanh(J/T)
thN= th**Ns
ch = 1/th
e = -J*( th + ch*thN )/( 1 + thN )
heat=((beta*J)**2)*(((1+thN+(Ns-1)*(th**2)+(Ns-1)*(ch**2)*thN)/(1+thN))-Ns*((th+ch*thN)/(1+thN))**2)

plt.subplot(2,2,1)
Temp, capMetro,stdMetro = np.loadtxt("isingData/h0/capMetro.dat", usecols = (0,2,3), unpack = True)
plt.errorbar(Temp, capMetro, yerr=stdMetro, label = "MC simulation: Metropolis", fmt = "bx", markersize = 10 , capsize = 5, elinewidth = 1)
plt.plot(T, heat, label = "Analytic results", color = "red")
plt.xlim(0,2.2)
plt.title('C: Metropolis sampling',fontsize = 12)
plt.xlabel('Temperature',fontsize = 12)
plt.ylabel('C',fontsize = 12)
plt.legend(loc = "best")
plt.grid('True')

plt.subplot(2,2,2)
Temp, capGibbs,stdGibbs = np.loadtxt("isingData/h0/capGibbs.dat", usecols = (0,2,3), unpack = True)
plt.errorbar(Temp, capGibbs, yerr=stdGibbs, label = "MC simulation: Gibbs", fmt = "ko", capsize = 5, elinewidth = 1)
plt.plot(T, heat, label = "Analytic results", color = "red")
plt.xlim(0,2.2)
plt.title('C: Gibbs sampling',fontsize = 12)
plt.xlabel('Temperature',fontsize = 12)
plt.ylabel('C',fontsize = 12)
plt.legend(loc = "best")
plt.grid('True')

plt.subplot(2,2,3)
Temp, capMetro,stdMetro = np.loadtxt("isingData/h0/capMetro.dat", usecols = (0,2,3), unpack = True)
plt.errorbar(Temp, capMetro, yerr=stdMetro, label = "MC simulation: Metropolis", fmt = "bx", markersize = 10 , capsize = 5, elinewidth = 1)
Temp, capGibbs,stdGibbs = np.loadtxt("isingData/h0/capGibbs.dat", usecols = (0,2,3), unpack = True)
plt.errorbar(Temp, capGibbs, yerr=stdGibbs, label = "MC simulation: Gibbs", fmt = "ko", capsize = 5, elinewidth = 1)
plt.plot(T, heat, label = "Analytic results", color = "red")
plt.xlim(0,2.2)
plt.title('C: Gibbs vs. Metropolis',fontsize = 12)
plt.xlabel('Temperature',fontsize = 12)
plt.ylabel('C',fontsize = 12)
plt.legend(loc = "best")
plt.grid('True')

# %% [markdown]
# ### MAGNETIC SUSCEPTIBILITY (h=0)

# %%
# chi(T)
plt.figure(figsize=(18,10))
points=100
T = np.linspace(0.2,3.0,num=points)
beta = 1/T
J = 1.0
Ns = 50
th = np.tanh(J/T)
thN= th**Ns
ch = 1/th
X = beta*np.exp(2*beta*J)*(1-thN)/(1+thN)




plt.subplot(2,2,1)
Temp, chiMetro,stdMetro = np.loadtxt("isingData/h0/chiMetro.dat", usecols = (0,2,3), unpack = True)
plt.errorbar(Temp, chiMetro, yerr=stdMetro, label = "MC simulation: Metropolis", fmt = "bx", markersize = 10 , capsize = 5, elinewidth = 1)
plt.plot(T, X, label = "Analytic results", color = "red")
plt.xlim(0,2.2)
plt.title('$\chi$: Metropolis sampling',fontsize = 12)
plt.xlabel('Temperature',fontsize = 12)
plt.ylabel('$\chi$',fontsize = 12)
plt.legend(loc = "best")
plt.grid('True')

plt.subplot(2,2,2)
Temp, chiGibbs,stdGibbs = np.loadtxt("isingData/h0/chiGibbs.dat", usecols = (0,2,3), unpack = True)
plt.errorbar(Temp, chiGibbs, yerr=stdGibbs, label = "MC simulation: Gibbs", fmt = "ko", capsize = 5, elinewidth = 1)
plt.plot(T, X, label = "Analytic results", color = "red")
plt.xlim(0,2.2)
plt.title('$\chi$: Gibbs sampling',fontsize = 12)
plt.xlabel('Temperature',fontsize = 12)
plt.ylabel('$\chi$',fontsize = 12)
plt.legend(loc = "best")
plt.grid('True')

plt.subplot(2,2,3)
Temp, chiMetro,stdMetro = np.loadtxt("isingData/h0/chiMetro.dat", usecols = (0,2,3), unpack = True)
plt.errorbar(Temp, chiMetro, yerr=stdMetro, label = "MC simulation: Metropolis", fmt = "bx", markersize = 10 , capsize = 5, elinewidth = 1)
Temp, chiGibbs,stdGibbs = np.loadtxt("isingData/h0/chiGibbs.dat", usecols = (0,2,3), unpack = True)
plt.errorbar(Temp, chiGibbs, yerr=stdGibbs, label = "MC simulation: Gibbs", fmt = "ko", capsize = 5, elinewidth = 1)
plt.plot(T, X, label = "Analytic results", color = "red")
plt.xlim(0,2.2)
plt.title('$\chi$: Gibbs vs. Metropolis',fontsize = 12)
plt.xlabel('Temperature',fontsize = 12)
plt.ylabel('$\chi$',fontsize = 12)
plt.legend(loc = "best")
plt.grid('True')

# %% [markdown]
# ### MAGNETIZATION (h = 0.02)

# %%
#Magnetization

plt.figure(figsize=(18,10))
h=0.02 #external field
points=100
T = np.linspace(0.2,3.0,num=points)
b = 1/T
l1 = np.exp(b*J)*np.cosh(b*h)+np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
l2 = np.exp(b*J)*np.cosh(b*h)-np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))
Z = l1**Ns + l2**Ns
M = (np.exp(b*J)*np.sinh(b*h)*((l1**(Ns-1))*(1+np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J))) 
        + (l2**(Ns-1))*(1-np.exp(b*J)*np.cosh(b*h)/np.sqrt(np.exp(2*b*J)*np.cosh(b*h)*np.cosh(b*h)-2*np.sinh(2*b*J)))))/(Z)


plt.subplot(2,2,1)
Temp, magMetro,stdMetro = np.loadtxt("isingData/h002/magM.dat", usecols = (0,2,3), unpack = True)
plt.errorbar(Temp, magMetro, yerr=stdMetro, label = "MC simulation: Metropolis", fmt = "bx", markersize = 10 , capsize = 5, elinewidth = 1)
plt.plot(T, M, label = "Analytic results", color = "red")
plt.xlim(0,2.2)
plt.title('M: Metropolis sampling',fontsize = 12)
plt.xlabel('Temperature',fontsize = 12)
plt.ylabel('M',fontsize = 12)
plt.legend(loc = "best")
plt.grid('True')

plt.subplot(2,2,2)
Temp, magGibbs,stdGibbs = np.loadtxt("isingData/h002/magG.dat", usecols = (0,2,3), unpack = True)
plt.errorbar(Temp, magGibbs, yerr=stdGibbs, label = "MC simulation: Gibbs", fmt = "ko", capsize = 5, elinewidth = 1)
plt.plot(T, M, label = "Analytic results", color = "red")
plt.xlim(0,2.2)
plt.title('M: Gibbs sampling',fontsize = 12)
plt.xlabel('Temperature',fontsize = 12)
plt.ylabel('M',fontsize = 12)
plt.legend(loc = "best")
plt.grid('True')

plt.subplot(2,2,3)
Temp, magMetro,stdMetro = np.loadtxt("isingData/h002/magM.dat", usecols = (0,2,3), unpack = True)
plt.errorbar(Temp, magMetro, yerr=stdMetro, label = "MC simulation: Metropolis", fmt = "bx", markersize = 10 , capsize = 5, elinewidth = 1)
Temp, chiGibbs,stdGibbs = np.loadtxt("isingData/h002/magG.dat", usecols = (0,2,3), unpack = True)
plt.errorbar(Temp, magGibbs, yerr=stdGibbs, label = "MC simulation: Gibbs", fmt = "ko", capsize = 5, elinewidth = 1)
plt.plot(T, M, label = "Analytic results", color = "red")
plt.xlim(0,2.2)
plt.title('M: Gibbs vs. Metropolis',fontsize = 12)
plt.xlabel('Temperature',fontsize = 12)
plt.ylabel('M',fontsize = 12)
plt.legend(loc = "best")
plt.grid('True')

# %% [markdown]
# ## RESULTS ANALYSIS

# %% [markdown]
# All the data used for producing these results have been obtained after the system was equilibrated, so that the probability of samplig the system and finding it in a parùrticular configuration is proportional to the Boltzmann weight, $p(\mu)$, which is given by the two sampling algorithms.
# The first consideration that can be formulated from this plots si that both sampling gives results that are fully comparable and equivalent.
# - Internal energy: the internal energy grows with the temperature, and when T tend to zero, it asymptotically tends to -1.The system starts with an initial random configuration with all spins down, and it naturally tends to allign them as the temperature decrease. Note that a complete allignment can be obtained only if  T = 0K.
# - Heat Capacity: for T in the range [0.5, 1], the heat capacity has a local maximum, given by the fact that the spins are beginning to allign themselves. The heat exchange in that range of temperature is the most efficient. As the temperature decreases, the heat capacity goes to zero, as the spin configuratios gets moer end more ordere.
# - $\chi(T)$ : as inidicated by the theoretical results, the magnetic susceptibility fastly increses as the temperature is lowered. This means that if, at lower temperatures, a small external field is applied to the sample, its response would be immediate, with a non-zero magnetization.
# - Magnetization:to compute the magnetization a non-zero external field must be applied. When T= 0K. M tends to 1, meaning that all the spins are alligned. As the temperature increase, the magnetization decreases, this because the field favours configurations with the spins up.

# %% [markdown]
# ### ZERO TEMPERATURE:
# By observing the data contained in "Dati_T0", we can check the limit for T=0k for the potential evergy and the heat capacity:
# - as prescribed by the theory they go to zero.
